# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYSHANKAR0205/ML-projects/blob/main/Customer_Behaviour_Analyser_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' A retail company wants to predict customer purchasing behaviour based on their Age, Salary and Past purchase history'''

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Generate dataframe
data={"Age":[25,27,30,32,20,41],"MonthlyIncome":[50000,80000,60000,30000,90000,65000],"NumberOfProductBuy":[1,2,3,2,4,3]}
label=np.array([1,2,1,0,2,1]) #0:Low , 1:Medium , 2:Large
df=pd.DataFrame(data)
df
# Out:
#    Age  MonthlyIncome  NumberOfProductBuy
# 0   25          50000                   1
# 1   27          80000                   2
# 2   30          60000                   3
# 3   32          30000                   2
# 4   20          90000                   4
# 5   41          65000                   3

# %%
#Train and Test Data
x=df[["Age","MonthlyIncome","NumberOfProductBuy"]]
y=label
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# Standardise the value
scalar=StandardScaler()
x_train=scalar.fit_transform(x_train)
x_test=scalar.fit_transform(x_test)

#Fit into KNN Model
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)

# Accuracy Score
accuracy=knn.score(x_test, y_test)
print(f"accuracy score:{accuracy}")
# Out:
# accuracy score:0.5

# %%
user_age=float(input("enter your age: "))
user_salary=float(input("enter your salary: "))
user_buy_product=int(input("enter your product: "))
user_input=np.array([[user_age,user_salary,user_buy_product]])
user_input_scalar=scalar.transform(user_input)
prediction=knn.predict(user_input_scalar)
print(prediction)
if prediction==0:
    print("customer is not good")
elif prediction==1:
    print("customer is good")
else:
    print("customer is very good")
# Out:
# enter your age: 34
# enter your salary: 60000
# enter your product: 5
# [1]
# customer is good
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
